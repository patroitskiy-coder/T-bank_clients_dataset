# %%
#Оценку клиента (review_mark) можно точно предсказать на основе текста отзыва и характеристик продукта/темы, поскольку они совместно отражают как конкретный пользовательский опыт, так и системные проблемы сервиса.

#таргет: бинарный
#фичи: длинна текста, количество знаков препинания, количество вопросов и восклицательных знаков, продукт (??)
#устойчивость: по платформам, по образованию
