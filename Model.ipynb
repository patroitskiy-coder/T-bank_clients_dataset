# %%
#теперь у нас есть ряд one-hot кодированных переменных. Давайте построим логистическую регресиию для предсказания хороший/ плохой ли отзыв.



# =========================
# MODEL 2: PERSONAL FEATURES
# ==========================

X_per = data_enc['one_per_cols'].astype(int)

# добавляем константу
X_per = sm.add_constant(X_per)

# обучаем модель
model_per = sm.Logit(y, X_per).fit()

# результаты
print(model_per.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 16
#      12 # целевая переменная
#      13 y = data_enc['review_bin'].astype(int)
#      14
#      15 # продуктовые признаки
# ---> 16 X_prod = data_enc[one_prod_cols].astype(int)
#      17
#      18 # добавляем константу
#      19 X_prod = sm.add_constant(X_prod)
#
# NameError: name 'one_prod_cols' is not defined
